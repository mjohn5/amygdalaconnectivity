# %%
import nibabel as nib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import tensorflow as tf
from tensorflow import keras

import numpy as np
import pandas as pd

from functools import partial

# %%
am_img_path = "C:/Users/Majnu/Desktop/MJ.Desk/Tossi/COBRE/Data.May.2023/Amygdala"

t1_am_name   = "A00000300_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t2_am_name   = "A00000368_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t3_am_name   = "A00000456_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t4_am_name   = "A00000541_0014_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t5_am_name   = "A00000838_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t6_am_name   = "A00000909_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t7_am_name   = "A00001181_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t8_am_name   = "A00001243_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t9_am_name   = "A00001251_0015_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t10_am_name  = "A00001452_0014_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y

t11_am_name   = "A00002198_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t12_am_name   = "A00002480_0014_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t13_am_name   = "A00003150_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t14_am_name   = "A00004087_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t15_am_name   = "A00004507_0014_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t16_am_name   = "A00006754_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t17_am_name   = "A00007409_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t18_am_name   = "A00009280_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t19_am_name   = "A00010150_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t20_am_name   = "A00010684_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y

t21_am_name   = "A00011265_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t22_am_name   = "A00011725_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t23_am_name   = "A00012767_0015_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t24_am_name   = "A00012995_0014_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t25_am_name   = "A00013140_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t26_am_name   = "A00013216_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t27_am_name   = "A00013363_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t28_am_name   = "A00013816_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t29_am_name   = "A00014120_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t30_am_name   = "A00014175_0010_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y

t31_am_name   = "A00014225_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t32_am_name   = "A00014590_0015_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t33_am_name   = "A00014607_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t34_am_name   = "A00014636_0015_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t35_am_name   = "A00014719_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t36_am_name   = "A00014804_0014_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t37_am_name   = "A00014830_0010_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t38_am_name   = "A00014839_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t39_am_name   = "A00014898_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t40_am_name   = "A00015201_0014_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y

t41_am_name   = "A00015518_0014_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t42_am_name   = "A00015648_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t43_am_name   = "A00015759_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t44_am_name   = "A00015826_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t45_am_name   = "A00016197_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t46_am_name   = "A00016720_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t47_am_name   = "A00016723_0014_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t48_am_name   = "A00017147_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t49_am_name   = "A00017294_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t50_am_name   = "A00018317_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y

t51_am_name   = "A00018403_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t52_am_name   = "A00018434_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t53_am_name   = "A00018553_0010_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t54_am_name   = "A00018716_0015_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t55_am_name   = "A00018979_0020_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t56_am_name   = "A00019293_0015_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t57_am_name   = "A00019349_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t58_am_name   = "A00019750_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t59_am_name   = "A00019888_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t60_am_name   = "A00020414_0014_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y

t61_am_name   = "A00020416_0014_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t62_am_name   = "A00020602_0014_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t63_am_name   = "A00020787_0017_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t64_am_name   = "A00020805_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t65_am_name   = "A00020895_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t66_am_name   = "A00020968_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t67_am_name   = "A00020984_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t68_am_name   = "A00021058_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t69_am_name   = "A00021072_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t70_am_name   = "A00021081_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y

t71_am_name   = "A00021085_0014_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t72_am_name   = "A00021591_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t73_am_name   = "A00021598_0010_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t74_am_name   = "A00022400_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t75_am_name   = "A00022490_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t76_am_name   = "A00022509_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t77_am_name   = "A00022592_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t78_am_name   = "A00022619_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t79_am_name   = "A00022653_0014_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t80_am_name   = "A00022687_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y

t81_am_name   = "A00022727_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t82_am_name   = "A00022729_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t83_am_name   = "A00022773_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t84_am_name   = "A00022810_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t85_am_name   = "A00022835_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t86_am_name   = "A00022837_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t87_am_name   = "A00022915_0014_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t88_am_name   = "A00023095_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t89_am_name   = "A00023120_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t90_am_name   = "A00023131_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y

t91_am_name   = "A00023143_0014_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t92_am_name   = "A00023158_0014_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t93_am_name   = "A00023243_0015_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t94_am_name   = "A00023246_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t95_am_name   = "A00023330_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t96_am_name   = "A00023337_0014_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t97_am_name   = "A00023590_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t98_am_name   = "A00023730_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t99_am_name   = "A00023750_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t100_am_name  = "A00023800_0014_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y

t101_am_name   = "A00023848_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t102_am_name   = "A00023866_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t103_am_name   = "A00024160_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t104_am_name   = "A00024198_0014_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t105_am_name   = "A00024228_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t106_am_name   = "A00024301_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t107_am_name   = "A00024372_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t108_am_name   = "A00024446_0009_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t109_am_name   = "A00024535_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t110_am_name   = "A00024546_0014_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y

t111_am_name   = "A00024568_0008_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t112_am_name   = "A00024663_0016_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t113_am_name   = "A00024684_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t114_am_name   = "A00024820_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t115_am_name   = "A00024932_0014_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t116_am_name   = "A00024953_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t117_am_name   = "A00024955_0015_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t118_am_name   = "A00024959_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t119_am_name   = "A00025969_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t120_am_name   = "A00026907_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y

t121_am_name   = "A00026945_0014_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t122_am_name   = "A00027391_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t123_am_name   = "A00027410_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t124_am_name   = "A00027487_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t125_am_name   = "A00027537_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t126_am_name   = "A00027755_0015_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t127_am_name   = "A00027787_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t128_am_name   = "A00027969_0011_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t129_am_name   = "A00028052_0010_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t130_am_name   = "A00028189_0010_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y

t131_am_name   = "A00028303_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t132_am_name   = "A00028402_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t133_am_name   = "A00028404_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t134_am_name   = "A00028405_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t135_am_name   = "A00028406_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t136_am_name   = "A00028408_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t137_am_name   = "A00028409_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t138_am_name   = "A00028805_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t139_am_name   = "A00028806_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t140_am_name   = "A00029226_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y

t141_am_name   = "A00029452_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t142_am_name   = "A00029486_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t143_am_name   = "A00031186_0014_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t144_am_name   = "A00031271_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t145_am_name   = "A00031478_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t146_am_name   = "A00031597_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t147_am_name   = "A00031764_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t148_am_name   = "A00033214_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t149_am_name   = "A00033648_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"   #n
t150_am_name   = "A00033686_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"   #n

t151_am_name   = "A00033715_0015_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"   #n
t152_am_name   = "A00033749_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"   #n
t153_am_name   = "A00033812_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"   #n
t154_am_name   = "A00033994_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"   #n
t155_am_name   = "A00034214_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"   #n
t156_am_name   = "A00034273_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t157_am_name   = "A00034381_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"   #n
t158_am_name   = "A00035003_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t159_am_name   = "A00035183_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"   #n
t160_am_name   = "A00035485_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y

t161_am_name   = "A00035751_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t162_am_name   = "A00035836_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t163_am_name   = "A00035859_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t164_am_name   = "A00036049_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t165_am_name   = "A00036555_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t166_am_name   = "A00036844_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t167_am_name   = "A00036897_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t168_am_name   = "A00036916_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t169_am_name   = "A00037007_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t170_am_name   = "A00037034_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y

t171_am_name   = "A00037224_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t172_am_name   = "A00037238_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t173_am_name   = "A00037318_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t174_am_name   = "A00037495_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t175_am_name   = "A00037564_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t176_am_name   = "A00037619_0013_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t177_am_name   = "A00037649_0014_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t178_am_name   = "A00037665_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t179_am_name   = "A00037854_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t180_am_name   = "A00038172_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y

t181_am_name   = "A00038441_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y
t182_am_name   = "A00038624_0012_AmygdalaB-HO50_Z_InStandard2mm.nii.gz"  #y

t1_am_img    = nib.load(f"{am_img_path}/{t1_am_name}")
t2_am_img    = nib.load(f"{am_img_path}/{t2_am_name}")
t3_am_img    = nib.load(f"{am_img_path}/{t3_am_name}")
t4_am_img    = nib.load(f"{am_img_path}/{t4_am_name}")
t5_am_img    = nib.load(f"{am_img_path}/{t5_am_name}")
t6_am_img    = nib.load(f"{am_img_path}/{t6_am_name}")
t7_am_img    = nib.load(f"{am_img_path}/{t7_am_name}")
t8_am_img    = nib.load(f"{am_img_path}/{t8_am_name}")
t9_am_img    = nib.load(f"{am_img_path}/{t9_am_name}")
t10_am_img   = nib.load(f"{am_img_path}/{t10_am_name}")
t11_am_img   = nib.load(f"{am_img_path}/{t11_am_name}")
t12_am_img   = nib.load(f"{am_img_path}/{t12_am_name}")
t13_am_img   = nib.load(f"{am_img_path}/{t13_am_name}")
t14_am_img   = nib.load(f"{am_img_path}/{t14_am_name}")
t15_am_img   = nib.load(f"{am_img_path}/{t15_am_name}")
t16_am_img   = nib.load(f"{am_img_path}/{t16_am_name}")
t17_am_img   = nib.load(f"{am_img_path}/{t17_am_name}")
t18_am_img   = nib.load(f"{am_img_path}/{t18_am_name}")
t19_am_img   = nib.load(f"{am_img_path}/{t19_am_name}")
t20_am_img   = nib.load(f"{am_img_path}/{t20_am_name}")
t21_am_img   = nib.load(f"{am_img_path}/{t21_am_name}")
t22_am_img   = nib.load(f"{am_img_path}/{t22_am_name}")
t23_am_img   = nib.load(f"{am_img_path}/{t23_am_name}")
t24_am_img   = nib.load(f"{am_img_path}/{t24_am_name}")
t25_am_img   = nib.load(f"{am_img_path}/{t25_am_name}")
t26_am_img   = nib.load(f"{am_img_path}/{t26_am_name}")
t27_am_img   = nib.load(f"{am_img_path}/{t27_am_name}")
t28_am_img   = nib.load(f"{am_img_path}/{t28_am_name}")
t29_am_img   = nib.load(f"{am_img_path}/{t29_am_name}")
t30_am_img   = nib.load(f"{am_img_path}/{t30_am_name}")
t31_am_img   = nib.load(f"{am_img_path}/{t31_am_name}")
t32_am_img   = nib.load(f"{am_img_path}/{t32_am_name}")
t33_am_img   = nib.load(f"{am_img_path}/{t33_am_name}")
t34_am_img   = nib.load(f"{am_img_path}/{t34_am_name}")
t35_am_img   = nib.load(f"{am_img_path}/{t35_am_name}")
t36_am_img   = nib.load(f"{am_img_path}/{t36_am_name}")
t37_am_img   = nib.load(f"{am_img_path}/{t37_am_name}")
t38_am_img   = nib.load(f"{am_img_path}/{t38_am_name}")
t39_am_img   = nib.load(f"{am_img_path}/{t39_am_name}")
t40_am_img   = nib.load(f"{am_img_path}/{t40_am_name}")
t41_am_img   = nib.load(f"{am_img_path}/{t41_am_name}")
t42_am_img   = nib.load(f"{am_img_path}/{t42_am_name}")
t43_am_img   = nib.load(f"{am_img_path}/{t43_am_name}")
t44_am_img   = nib.load(f"{am_img_path}/{t44_am_name}")
t45_am_img   = nib.load(f"{am_img_path}/{t45_am_name}")
t46_am_img   = nib.load(f"{am_img_path}/{t46_am_name}")
t47_am_img   = nib.load(f"{am_img_path}/{t47_am_name}")
t48_am_img   = nib.load(f"{am_img_path}/{t48_am_name}")
t49_am_img   = nib.load(f"{am_img_path}/{t49_am_name}")
t50_am_img   = nib.load(f"{am_img_path}/{t50_am_name}")
t51_am_img   = nib.load(f"{am_img_path}/{t51_am_name}")
t52_am_img   = nib.load(f"{am_img_path}/{t52_am_name}")
t53_am_img   = nib.load(f"{am_img_path}/{t53_am_name}")
t54_am_img   = nib.load(f"{am_img_path}/{t54_am_name}")
t55_am_img   = nib.load(f"{am_img_path}/{t55_am_name}")
t56_am_img   = nib.load(f"{am_img_path}/{t56_am_name}")
t57_am_img   = nib.load(f"{am_img_path}/{t57_am_name}")
t58_am_img   = nib.load(f"{am_img_path}/{t58_am_name}")
t59_am_img   = nib.load(f"{am_img_path}/{t59_am_name}")
t60_am_img   = nib.load(f"{am_img_path}/{t60_am_name}")
t61_am_img   = nib.load(f"{am_img_path}/{t61_am_name}")
t62_am_img   = nib.load(f"{am_img_path}/{t62_am_name}")
t63_am_img   = nib.load(f"{am_img_path}/{t63_am_name}")
t64_am_img   = nib.load(f"{am_img_path}/{t64_am_name}")
t65_am_img   = nib.load(f"{am_img_path}/{t65_am_name}")
t66_am_img   = nib.load(f"{am_img_path}/{t66_am_name}")
t67_am_img   = nib.load(f"{am_img_path}/{t67_am_name}")
t68_am_img   = nib.load(f"{am_img_path}/{t68_am_name}")
t69_am_img   = nib.load(f"{am_img_path}/{t69_am_name}")
t70_am_img   = nib.load(f"{am_img_path}/{t70_am_name}")
t71_am_img   = nib.load(f"{am_img_path}/{t71_am_name}")
t72_am_img   = nib.load(f"{am_img_path}/{t72_am_name}")
t73_am_img   = nib.load(f"{am_img_path}/{t73_am_name}")
t74_am_img   = nib.load(f"{am_img_path}/{t74_am_name}")
t75_am_img   = nib.load(f"{am_img_path}/{t75_am_name}")
t76_am_img   = nib.load(f"{am_img_path}/{t76_am_name}")
t77_am_img   = nib.load(f"{am_img_path}/{t77_am_name}")
t78_am_img   = nib.load(f"{am_img_path}/{t78_am_name}")
t79_am_img   = nib.load(f"{am_img_path}/{t79_am_name}")
t80_am_img   = nib.load(f"{am_img_path}/{t80_am_name}")
t81_am_img   = nib.load(f"{am_img_path}/{t81_am_name}")
t82_am_img   = nib.load(f"{am_img_path}/{t82_am_name}")
t83_am_img   = nib.load(f"{am_img_path}/{t83_am_name}")
t84_am_img   = nib.load(f"{am_img_path}/{t84_am_name}")
t85_am_img   = nib.load(f"{am_img_path}/{t85_am_name}")
t86_am_img   = nib.load(f"{am_img_path}/{t86_am_name}")
t87_am_img   = nib.load(f"{am_img_path}/{t87_am_name}")
t88_am_img   = nib.load(f"{am_img_path}/{t88_am_name}")
t89_am_img   = nib.load(f"{am_img_path}/{t89_am_name}")
t90_am_img   = nib.load(f"{am_img_path}/{t90_am_name}")
t91_am_img   = nib.load(f"{am_img_path}/{t91_am_name}")
t92_am_img   = nib.load(f"{am_img_path}/{t92_am_name}")
t93_am_img   = nib.load(f"{am_img_path}/{t93_am_name}")
t94_am_img   = nib.load(f"{am_img_path}/{t94_am_name}")
t95_am_img   = nib.load(f"{am_img_path}/{t95_am_name}")
t96_am_img   = nib.load(f"{am_img_path}/{t96_am_name}")
t97_am_img   = nib.load(f"{am_img_path}/{t97_am_name}")
t98_am_img   = nib.load(f"{am_img_path}/{t98_am_name}")
t99_am_img   = nib.load(f"{am_img_path}/{t99_am_name}")
t100_am_img  = nib.load(f"{am_img_path}/{t100_am_name}")

t101_am_img   = nib.load(f"{am_img_path}/{t101_am_name}")
t102_am_img   = nib.load(f"{am_img_path}/{t102_am_name}")
t103_am_img   = nib.load(f"{am_img_path}/{t103_am_name}")
t104_am_img   = nib.load(f"{am_img_path}/{t104_am_name}")
t105_am_img   = nib.load(f"{am_img_path}/{t105_am_name}")
t106_am_img   = nib.load(f"{am_img_path}/{t106_am_name}")
t107_am_img   = nib.load(f"{am_img_path}/{t107_am_name}")
t108_am_img   = nib.load(f"{am_img_path}/{t108_am_name}")
t109_am_img   = nib.load(f"{am_img_path}/{t109_am_name}")
t110_am_img   = nib.load(f"{am_img_path}/{t110_am_name}")
t111_am_img   = nib.load(f"{am_img_path}/{t111_am_name}")
t112_am_img   = nib.load(f"{am_img_path}/{t112_am_name}")
t113_am_img   = nib.load(f"{am_img_path}/{t113_am_name}")
t114_am_img   = nib.load(f"{am_img_path}/{t114_am_name}")
t115_am_img   = nib.load(f"{am_img_path}/{t115_am_name}")
t116_am_img   = nib.load(f"{am_img_path}/{t116_am_name}")
t117_am_img   = nib.load(f"{am_img_path}/{t117_am_name}")
t118_am_img   = nib.load(f"{am_img_path}/{t118_am_name}")
t119_am_img   = nib.load(f"{am_img_path}/{t119_am_name}")
t120_am_img   = nib.load(f"{am_img_path}/{t120_am_name}")
t121_am_img   = nib.load(f"{am_img_path}/{t121_am_name}")
t122_am_img   = nib.load(f"{am_img_path}/{t122_am_name}")
t123_am_img   = nib.load(f"{am_img_path}/{t123_am_name}")
t124_am_img   = nib.load(f"{am_img_path}/{t124_am_name}")
t125_am_img   = nib.load(f"{am_img_path}/{t125_am_name}")
t126_am_img   = nib.load(f"{am_img_path}/{t126_am_name}")
t127_am_img   = nib.load(f"{am_img_path}/{t127_am_name}")
t128_am_img   = nib.load(f"{am_img_path}/{t128_am_name}")
t129_am_img   = nib.load(f"{am_img_path}/{t129_am_name}")
t130_am_img   = nib.load(f"{am_img_path}/{t130_am_name}")
t131_am_img   = nib.load(f"{am_img_path}/{t131_am_name}")
t132_am_img   = nib.load(f"{am_img_path}/{t132_am_name}")
t133_am_img   = nib.load(f"{am_img_path}/{t133_am_name}")
t134_am_img   = nib.load(f"{am_img_path}/{t134_am_name}")
t135_am_img   = nib.load(f"{am_img_path}/{t135_am_name}")
t136_am_img   = nib.load(f"{am_img_path}/{t136_am_name}")
t137_am_img   = nib.load(f"{am_img_path}/{t137_am_name}")
t138_am_img   = nib.load(f"{am_img_path}/{t138_am_name}")
t139_am_img   = nib.load(f"{am_img_path}/{t139_am_name}")
t140_am_img   = nib.load(f"{am_img_path}/{t140_am_name}")
t141_am_img   = nib.load(f"{am_img_path}/{t141_am_name}")
t142_am_img   = nib.load(f"{am_img_path}/{t142_am_name}")
t143_am_img   = nib.load(f"{am_img_path}/{t143_am_name}")
t144_am_img   = nib.load(f"{am_img_path}/{t144_am_name}")
t145_am_img   = nib.load(f"{am_img_path}/{t145_am_name}")
t146_am_img   = nib.load(f"{am_img_path}/{t146_am_name}")
t147_am_img   = nib.load(f"{am_img_path}/{t147_am_name}")
t148_am_img   = nib.load(f"{am_img_path}/{t148_am_name}")
t149_am_img   = nib.load(f"{am_img_path}/{t149_am_name}")
t150_am_img   = nib.load(f"{am_img_path}/{t150_am_name}")
t151_am_img   = nib.load(f"{am_img_path}/{t151_am_name}")
t152_am_img   = nib.load(f"{am_img_path}/{t152_am_name}")
t153_am_img   = nib.load(f"{am_img_path}/{t153_am_name}")
t154_am_img   = nib.load(f"{am_img_path}/{t154_am_name}")
t155_am_img   = nib.load(f"{am_img_path}/{t155_am_name}")
t156_am_img   = nib.load(f"{am_img_path}/{t156_am_name}")
t157_am_img   = nib.load(f"{am_img_path}/{t157_am_name}")
t158_am_img   = nib.load(f"{am_img_path}/{t158_am_name}")
t159_am_img   = nib.load(f"{am_img_path}/{t159_am_name}")
t160_am_img   = nib.load(f"{am_img_path}/{t160_am_name}")
t161_am_img   = nib.load(f"{am_img_path}/{t161_am_name}")
t162_am_img   = nib.load(f"{am_img_path}/{t162_am_name}")
t163_am_img   = nib.load(f"{am_img_path}/{t163_am_name}")
t164_am_img   = nib.load(f"{am_img_path}/{t164_am_name}")
t165_am_img   = nib.load(f"{am_img_path}/{t165_am_name}")
t166_am_img   = nib.load(f"{am_img_path}/{t166_am_name}")
t167_am_img   = nib.load(f"{am_img_path}/{t167_am_name}")
t168_am_img   = nib.load(f"{am_img_path}/{t168_am_name}")
t169_am_img   = nib.load(f"{am_img_path}/{t169_am_name}")
t170_am_img   = nib.load(f"{am_img_path}/{t170_am_name}")
t171_am_img   = nib.load(f"{am_img_path}/{t171_am_name}")
t172_am_img   = nib.load(f"{am_img_path}/{t172_am_name}")
t173_am_img   = nib.load(f"{am_img_path}/{t173_am_name}")
t174_am_img   = nib.load(f"{am_img_path}/{t174_am_name}")
t175_am_img   = nib.load(f"{am_img_path}/{t175_am_name}")
t176_am_img   = nib.load(f"{am_img_path}/{t176_am_name}")
t177_am_img   = nib.load(f"{am_img_path}/{t177_am_name}")
t178_am_img   = nib.load(f"{am_img_path}/{t178_am_name}")
t179_am_img   = nib.load(f"{am_img_path}/{t179_am_name}")
t180_am_img   = nib.load(f"{am_img_path}/{t180_am_name}")
t181_am_img   = nib.load(f"{am_img_path}/{t181_am_name}")
t182_am_img   = nib.load(f"{am_img_path}/{t182_am_name}")

# %%
t1_am_img_data  = t1_am_img.get_fdata()
t2_am_img_data  = t2_am_img.get_fdata()
t3_am_img_data  = t3_am_img.get_fdata()
t4_am_img_data  = t4_am_img.get_fdata()
t5_am_img_data  = t5_am_img.get_fdata()
t6_am_img_data  = t6_am_img.get_fdata()
t7_am_img_data  = t7_am_img.get_fdata()
t8_am_img_data  = t8_am_img.get_fdata()
t9_am_img_data  = t9_am_img.get_fdata()
t10_am_img_data = t10_am_img.get_fdata()
t11_am_img_data  = t11_am_img.get_fdata()
t12_am_img_data  = t12_am_img.get_fdata()
t13_am_img_data  = t13_am_img.get_fdata()
t14_am_img_data  = t14_am_img.get_fdata()
t15_am_img_data  = t15_am_img.get_fdata()
t16_am_img_data  = t16_am_img.get_fdata()
t17_am_img_data  = t17_am_img.get_fdata()
t18_am_img_data  = t18_am_img.get_fdata()
t19_am_img_data  = t19_am_img.get_fdata()
t20_am_img_data  = t20_am_img.get_fdata()
t21_am_img_data  = t21_am_img.get_fdata()
t22_am_img_data  = t22_am_img.get_fdata()
t23_am_img_data  = t23_am_img.get_fdata()
t24_am_img_data  = t24_am_img.get_fdata()
t25_am_img_data  = t25_am_img.get_fdata()
t26_am_img_data  = t26_am_img.get_fdata()
t27_am_img_data  = t27_am_img.get_fdata()
t28_am_img_data  = t28_am_img.get_fdata()
t29_am_img_data  = t29_am_img.get_fdata()
t30_am_img_data  = t30_am_img.get_fdata()
t31_am_img_data  = t31_am_img.get_fdata()
t32_am_img_data  = t32_am_img.get_fdata()
t33_am_img_data  = t33_am_img.get_fdata()
t34_am_img_data  = t34_am_img.get_fdata()
t35_am_img_data  = t35_am_img.get_fdata()
t36_am_img_data  = t36_am_img.get_fdata()
t37_am_img_data  = t37_am_img.get_fdata()
t38_am_img_data  = t38_am_img.get_fdata()
t39_am_img_data  = t39_am_img.get_fdata()
t40_am_img_data  = t40_am_img.get_fdata()
t41_am_img_data  = t41_am_img.get_fdata()
t42_am_img_data  = t42_am_img.get_fdata()
t43_am_img_data  = t43_am_img.get_fdata()
t44_am_img_data  = t44_am_img.get_fdata()
t45_am_img_data  = t45_am_img.get_fdata()
t46_am_img_data  = t46_am_img.get_fdata()
t47_am_img_data  = t47_am_img.get_fdata()
t48_am_img_data  = t48_am_img.get_fdata()
t49_am_img_data  = t49_am_img.get_fdata()
t50_am_img_data  = t50_am_img.get_fdata()
t51_am_img_data  = t51_am_img.get_fdata()
t52_am_img_data  = t52_am_img.get_fdata()
t53_am_img_data  = t53_am_img.get_fdata()
t54_am_img_data  = t54_am_img.get_fdata()
t55_am_img_data  = t55_am_img.get_fdata()
t56_am_img_data  = t56_am_img.get_fdata()
t57_am_img_data  = t57_am_img.get_fdata()
t58_am_img_data  = t58_am_img.get_fdata()
t59_am_img_data  = t59_am_img.get_fdata()
t60_am_img_data  = t60_am_img.get_fdata()
t61_am_img_data  = t61_am_img.get_fdata()
t62_am_img_data  = t62_am_img.get_fdata()
t63_am_img_data  = t63_am_img.get_fdata()
t64_am_img_data  = t64_am_img.get_fdata()
t65_am_img_data  = t65_am_img.get_fdata()
t66_am_img_data  = t66_am_img.get_fdata()
t67_am_img_data  = t67_am_img.get_fdata()
t68_am_img_data  = t68_am_img.get_fdata()
t69_am_img_data  = t69_am_img.get_fdata()
t70_am_img_data  = t70_am_img.get_fdata()
t71_am_img_data  = t71_am_img.get_fdata()
t72_am_img_data  = t72_am_img.get_fdata()
t73_am_img_data  = t73_am_img.get_fdata()
t74_am_img_data  = t74_am_img.get_fdata()
t75_am_img_data  = t75_am_img.get_fdata()
t76_am_img_data  = t76_am_img.get_fdata()
t77_am_img_data  = t77_am_img.get_fdata()
t78_am_img_data  = t78_am_img.get_fdata()
t79_am_img_data  = t79_am_img.get_fdata()
t80_am_img_data  = t80_am_img.get_fdata()
t81_am_img_data  = t81_am_img.get_fdata()
t82_am_img_data  = t82_am_img.get_fdata()
t83_am_img_data  = t83_am_img.get_fdata()
t84_am_img_data  = t84_am_img.get_fdata()
t85_am_img_data  = t85_am_img.get_fdata()
t86_am_img_data  = t86_am_img.get_fdata()
t87_am_img_data  = t87_am_img.get_fdata()
t88_am_img_data  = t88_am_img.get_fdata() 
t89_am_img_data  = t89_am_img.get_fdata()
t90_am_img_data  = t90_am_img.get_fdata()
t91_am_img_data  = t91_am_img.get_fdata()
t92_am_img_data  = t92_am_img.get_fdata()
t93_am_img_data  = t93_am_img.get_fdata()
t94_am_img_data  = t94_am_img.get_fdata()
t95_am_img_data  = t95_am_img.get_fdata()
t96_am_img_data  = t96_am_img.get_fdata()
t97_am_img_data  = t97_am_img.get_fdata()
t98_am_img_data  = t98_am_img.get_fdata()
t99_am_img_data  = t99_am_img.get_fdata()
t100_am_img_data = t100_am_img.get_fdata()
t101_am_img_data  = t101_am_img.get_fdata()
t102_am_img_data  = t102_am_img.get_fdata()
t103_am_img_data  = t103_am_img.get_fdata()
t104_am_img_data  = t104_am_img.get_fdata()
t105_am_img_data  = t105_am_img.get_fdata()
t106_am_img_data  = t106_am_img.get_fdata()
t107_am_img_data  = t107_am_img.get_fdata()
t108_am_img_data  = t108_am_img.get_fdata()
t109_am_img_data  = t109_am_img.get_fdata()
t110_am_img_data = t110_am_img.get_fdata()
t111_am_img_data  = t111_am_img.get_fdata()
t112_am_img_data  = t112_am_img.get_fdata()
t113_am_img_data  = t113_am_img.get_fdata()
t114_am_img_data  = t114_am_img.get_fdata()
t115_am_img_data  = t115_am_img.get_fdata()
t116_am_img_data  = t116_am_img.get_fdata()
t117_am_img_data  = t117_am_img.get_fdata()
t118_am_img_data  = t118_am_img.get_fdata()
t119_am_img_data  = t119_am_img.get_fdata()
t120_am_img_data  = t120_am_img.get_fdata()
t121_am_img_data  = t121_am_img.get_fdata()
t122_am_img_data  = t122_am_img.get_fdata()
t123_am_img_data  = t123_am_img.get_fdata()
t124_am_img_data  = t124_am_img.get_fdata()
t125_am_img_data  = t125_am_img.get_fdata()
t126_am_img_data  = t126_am_img.get_fdata()
t127_am_img_data  = t127_am_img.get_fdata()
t128_am_img_data  = t128_am_img.get_fdata()
t129_am_img_data  = t129_am_img.get_fdata()
t130_am_img_data  = t130_am_img.get_fdata()
t131_am_img_data  = t131_am_img.get_fdata()
t132_am_img_data  = t132_am_img.get_fdata()
t133_am_img_data  = t133_am_img.get_fdata()
t134_am_img_data  = t134_am_img.get_fdata()
t135_am_img_data  = t135_am_img.get_fdata()
t136_am_img_data  = t136_am_img.get_fdata()
t137_am_img_data  = t137_am_img.get_fdata()
t138_am_img_data  = t138_am_img.get_fdata()
t139_am_img_data  = t139_am_img.get_fdata()
t140_am_img_data  = t140_am_img.get_fdata()
t141_am_img_data  = t141_am_img.get_fdata()
t142_am_img_data  = t142_am_img.get_fdata()
t143_am_img_data  = t143_am_img.get_fdata()
t144_am_img_data  = t144_am_img.get_fdata()
t145_am_img_data  = t145_am_img.get_fdata()
t146_am_img_data  = t146_am_img.get_fdata()
t147_am_img_data  = t147_am_img.get_fdata()
t148_am_img_data  = t148_am_img.get_fdata()
t149_am_img_data  = t149_am_img.get_fdata()
t150_am_img_data  = t150_am_img.get_fdata()
t151_am_img_data  = t151_am_img.get_fdata()
t152_am_img_data  = t152_am_img.get_fdata()
t153_am_img_data  = t153_am_img.get_fdata()
t154_am_img_data  = t154_am_img.get_fdata()
t155_am_img_data  = t155_am_img.get_fdata()
t156_am_img_data  = t156_am_img.get_fdata()
t157_am_img_data  = t157_am_img.get_fdata()
t158_am_img_data  = t158_am_img.get_fdata()
t159_am_img_data  = t159_am_img.get_fdata()
t160_am_img_data  = t160_am_img.get_fdata()
t161_am_img_data  = t161_am_img.get_fdata()
t162_am_img_data  = t162_am_img.get_fdata()
t163_am_img_data  = t163_am_img.get_fdata()
t164_am_img_data  = t164_am_img.get_fdata()
t165_am_img_data  = t165_am_img.get_fdata()
t166_am_img_data  = t166_am_img.get_fdata()
t167_am_img_data  = t167_am_img.get_fdata()
t168_am_img_data  = t168_am_img.get_fdata()
t169_am_img_data  = t169_am_img.get_fdata()
t170_am_img_data  = t170_am_img.get_fdata()
t171_am_img_data  = t171_am_img.get_fdata()
t172_am_img_data  = t172_am_img.get_fdata()
t173_am_img_data  = t173_am_img.get_fdata()
t174_am_img_data  = t174_am_img.get_fdata()
t175_am_img_data  = t175_am_img.get_fdata()
t176_am_img_data  = t176_am_img.get_fdata()
t177_am_img_data  = t177_am_img.get_fdata()
t178_am_img_data  = t178_am_img.get_fdata()
t179_am_img_data  = t179_am_img.get_fdata()
t180_am_img_data  = t180_am_img.get_fdata()
t181_am_img_data  = t181_am_img.get_fdata()
t182_am_img_data  = t182_am_img.get_fdata()

# %%
amc1  = t1_am_img_data[np.newaxis, :, :, :]
amc2  = t2_am_img_data[np.newaxis, :, :, :]
amc3  = t3_am_img_data[np.newaxis, :, :, :]
amc4  = t4_am_img_data[np.newaxis, :, :, :]
amc5  = t5_am_img_data[np.newaxis, :, :, :]
amc6  = t6_am_img_data[np.newaxis, :, :, :]
amc7  = t7_am_img_data[np.newaxis, :, :, :]
amc8  = t8_am_img_data[np.newaxis, :, :, :]
amc9  = t9_am_img_data[np.newaxis, :, :, :]
amc10 = t10_am_img_data[np.newaxis, :, :, :]
amc11  = t11_am_img_data[np.newaxis, :, :, :]
amc12  = t12_am_img_data[np.newaxis, :, :, :]
amc13  = t13_am_img_data[np.newaxis, :, :, :]
amc14  = t14_am_img_data[np.newaxis, :, :, :]
amc15  = t15_am_img_data[np.newaxis, :, :, :]
amc16  = t16_am_img_data[np.newaxis, :, :, :]
amc17  = t17_am_img_data[np.newaxis, :, :, :]
amc18  = t18_am_img_data[np.newaxis, :, :, :]
amc19  = t19_am_img_data[np.newaxis, :, :, :]
amc20  = t20_am_img_data[np.newaxis, :, :, :]
amc21  = t21_am_img_data[np.newaxis, :, :, :]
amc22  = t22_am_img_data[np.newaxis, :, :, :]
amc23  = t23_am_img_data[np.newaxis, :, :, :]
amc24  = t24_am_img_data[np.newaxis, :, :, :]
amc25  = t25_am_img_data[np.newaxis, :, :, :]
amc26  = t26_am_img_data[np.newaxis, :, :, :]
amc27  = t27_am_img_data[np.newaxis, :, :, :]
amc28  = t28_am_img_data[np.newaxis, :, :, :]
amc29  = t29_am_img_data[np.newaxis, :, :, :]
amc30  = t30_am_img_data[np.newaxis, :, :, :]
amc31  = t31_am_img_data[np.newaxis, :, :, :]
amc32  = t32_am_img_data[np.newaxis, :, :, :]
amc33  = t33_am_img_data[np.newaxis, :, :, :]
amc34  = t34_am_img_data[np.newaxis, :, :, :]
amc35  = t35_am_img_data[np.newaxis, :, :, :]
amc36  = t36_am_img_data[np.newaxis, :, :, :]
amc37  = t37_am_img_data[np.newaxis, :, :, :]
amc38  = t38_am_img_data[np.newaxis, :, :, :]
amc39  = t39_am_img_data[np.newaxis, :, :, :]
amc40  = t40_am_img_data[np.newaxis, :, :, :]
amc41  = t41_am_img_data[np.newaxis, :, :, :]
amc42  = t42_am_img_data[np.newaxis, :, :, :]
amc43  = t43_am_img_data[np.newaxis, :, :, :]
amc44  = t44_am_img_data[np.newaxis, :, :, :]
amc45  = t45_am_img_data[np.newaxis, :, :, :]
amc46  = t46_am_img_data[np.newaxis, :, :, :]
amc47  = t47_am_img_data[np.newaxis, :, :, :]
amc48  = t48_am_img_data[np.newaxis, :, :, :]
amc49  = t49_am_img_data[np.newaxis, :, :, :]
amc50  = t50_am_img_data[np.newaxis, :, :, :]
amc51  = t51_am_img_data[np.newaxis, :, :, :]
amc52  = t52_am_img_data[np.newaxis, :, :, :]
amc53  = t53_am_img_data[np.newaxis, :, :, :]
amc54  = t54_am_img_data[np.newaxis, :, :, :]
amc55  = t55_am_img_data[np.newaxis, :, :, :]
amc56  = t56_am_img_data[np.newaxis, :, :, :]
amc57  = t57_am_img_data[np.newaxis, :, :, :]
amc58  = t58_am_img_data[np.newaxis, :, :, :]
amc59  = t59_am_img_data[np.newaxis, :, :, :]
amc60  = t60_am_img_data[np.newaxis, :, :, :]
amc61  = t61_am_img_data[np.newaxis, :, :, :]
amc62  = t62_am_img_data[np.newaxis, :, :, :]
amc63  = t63_am_img_data[np.newaxis, :, :, :]
amc64  = t64_am_img_data[np.newaxis, :, :, :]
amc65  = t65_am_img_data[np.newaxis, :, :, :]
amc66  = t66_am_img_data[np.newaxis, :, :, :]
amc67  = t67_am_img_data[np.newaxis, :, :, :]
amc68  = t68_am_img_data[np.newaxis, :, :, :]
amc69  = t69_am_img_data[np.newaxis, :, :, :]
amc70  = t70_am_img_data[np.newaxis, :, :, :]
amc71  = t71_am_img_data[np.newaxis, :, :, :]
amc72  = t72_am_img_data[np.newaxis, :, :, :]
amc73  = t73_am_img_data[np.newaxis, :, :, :]
amc74  = t74_am_img_data[np.newaxis, :, :, :]
amc75  = t75_am_img_data[np.newaxis, :, :, :]
amc76  = t76_am_img_data[np.newaxis, :, :, :]
amc77  = t77_am_img_data[np.newaxis, :, :, :]
amc78  = t78_am_img_data[np.newaxis, :, :, :]
amc79  = t79_am_img_data[np.newaxis, :, :, :]
amc80  = t80_am_img_data[np.newaxis, :, :, :]
amc81  = t81_am_img_data[np.newaxis, :, :, :]
amc82  = t82_am_img_data[np.newaxis, :, :, :]
amc83  = t83_am_img_data[np.newaxis, :, :, :]
amc84  = t84_am_img_data[np.newaxis, :, :, :]
amc85  = t85_am_img_data[np.newaxis, :, :, :]
amc86  = t86_am_img_data[np.newaxis, :, :, :]
amc87  = t87_am_img_data[np.newaxis, :, :, :]
amc88  = t88_am_img_data[np.newaxis, :, :, :]
amc89  = t89_am_img_data[np.newaxis, :, :, :]
amc90  = t90_am_img_data[np.newaxis, :, :, :]
amc91  = t91_am_img_data[np.newaxis, :, :, :]
amc92  = t92_am_img_data[np.newaxis, :, :, :]
amc93  = t93_am_img_data[np.newaxis, :, :, :]
amc94  = t94_am_img_data[np.newaxis, :, :, :]
amc95  = t95_am_img_data[np.newaxis, :, :, :]
amc96  = t96_am_img_data[np.newaxis, :, :, :]
amc97  = t97_am_img_data[np.newaxis, :, :, :]
amc98  = t98_am_img_data[np.newaxis, :, :, :]
amc99  = t99_am_img_data[np.newaxis, :, :, :]
amc100 = t100_am_img_data[np.newaxis, :, :, :]
amc101  = t101_am_img_data[np.newaxis, :, :, :]
amc102  = t102_am_img_data[np.newaxis, :, :, :]
amc103  = t103_am_img_data[np.newaxis, :, :, :]
amc104  = t104_am_img_data[np.newaxis, :, :, :]
amc105  = t105_am_img_data[np.newaxis, :, :, :]
amc106  = t106_am_img_data[np.newaxis, :, :, :]
amc107  = t107_am_img_data[np.newaxis, :, :, :]
amc108  = t108_am_img_data[np.newaxis, :, :, :]
amc109  = t109_am_img_data[np.newaxis, :, :, :]
amc110 = t110_am_img_data[np.newaxis, :, :, :]
amc111  = t111_am_img_data[np.newaxis, :, :, :]
amc112  = t112_am_img_data[np.newaxis, :, :, :]
amc113  = t113_am_img_data[np.newaxis, :, :, :]
amc114  = t114_am_img_data[np.newaxis, :, :, :]
amc115  = t115_am_img_data[np.newaxis, :, :, :]
amc116  = t116_am_img_data[np.newaxis, :, :, :]
amc117  = t117_am_img_data[np.newaxis, :, :, :]
amc118  = t118_am_img_data[np.newaxis, :, :, :]
amc119  = t119_am_img_data[np.newaxis, :, :, :]
amc120  = t120_am_img_data[np.newaxis, :, :, :]
amc121  = t121_am_img_data[np.newaxis, :, :, :]
amc122  = t122_am_img_data[np.newaxis, :, :, :]
amc123  = t123_am_img_data[np.newaxis, :, :, :]
amc124  = t124_am_img_data[np.newaxis, :, :, :]
amc125  = t125_am_img_data[np.newaxis, :, :, :]
amc126  = t126_am_img_data[np.newaxis, :, :, :]
amc127  = t127_am_img_data[np.newaxis, :, :, :]
amc128  = t128_am_img_data[np.newaxis, :, :, :]
amc129  = t129_am_img_data[np.newaxis, :, :, :]
amc130  = t130_am_img_data[np.newaxis, :, :, :]
amc131  = t131_am_img_data[np.newaxis, :, :, :]
amc132  = t132_am_img_data[np.newaxis, :, :, :]
amc133  = t133_am_img_data[np.newaxis, :, :, :]
amc134  = t134_am_img_data[np.newaxis, :, :, :]
amc135  = t135_am_img_data[np.newaxis, :, :, :]
amc136  = t136_am_img_data[np.newaxis, :, :, :]
amc137  = t137_am_img_data[np.newaxis, :, :, :]
amc138  = t138_am_img_data[np.newaxis, :, :, :]
amc139  = t139_am_img_data[np.newaxis, :, :, :]
amc140  = t140_am_img_data[np.newaxis, :, :, :]
amc141  = t141_am_img_data[np.newaxis, :, :, :]
amc142  = t142_am_img_data[np.newaxis, :, :, :]
amc143  = t143_am_img_data[np.newaxis, :, :, :]
amc144  = t144_am_img_data[np.newaxis, :, :, :]
amc145  = t145_am_img_data[np.newaxis, :, :, :]
amc146  = t146_am_img_data[np.newaxis, :, :, :]
amc147  = t147_am_img_data[np.newaxis, :, :, :]
amc148  = t148_am_img_data[np.newaxis, :, :, :]
amc149  = t149_am_img_data[np.newaxis, :, :, :]
amc150  = t150_am_img_data[np.newaxis, :, :, :]
amc151  = t151_am_img_data[np.newaxis, :, :, :]
amc152  = t152_am_img_data[np.newaxis, :, :, :]
amc153  = t153_am_img_data[np.newaxis, :, :, :]
amc154  = t154_am_img_data[np.newaxis, :, :, :]
amc155  = t155_am_img_data[np.newaxis, :, :, :]
amc156  = t156_am_img_data[np.newaxis, :, :, :]
amc157  = t157_am_img_data[np.newaxis, :, :, :]
amc158  = t158_am_img_data[np.newaxis, :, :, :]
amc159  = t159_am_img_data[np.newaxis, :, :, :]
amc160  = t160_am_img_data[np.newaxis, :, :, :]
amc161  = t161_am_img_data[np.newaxis, :, :, :]
amc162  = t162_am_img_data[np.newaxis, :, :, :]
amc163  = t163_am_img_data[np.newaxis, :, :, :]
amc164  = t164_am_img_data[np.newaxis, :, :, :]
amc165  = t165_am_img_data[np.newaxis, :, :, :]
amc166  = t166_am_img_data[np.newaxis, :, :, :]
amc167  = t167_am_img_data[np.newaxis, :, :, :]
amc168  = t168_am_img_data[np.newaxis, :, :, :]
amc169  = t169_am_img_data[np.newaxis, :, :, :]
amc170  = t170_am_img_data[np.newaxis, :, :, :]
amc171  = t171_am_img_data[np.newaxis, :, :, :]
amc172  = t172_am_img_data[np.newaxis, :, :, :]
amc173  = t173_am_img_data[np.newaxis, :, :, :]
amc174  = t174_am_img_data[np.newaxis, :, :, :]
amc175  = t175_am_img_data[np.newaxis, :, :, :]
amc176  = t176_am_img_data[np.newaxis, :, :, :]
amc177  = t177_am_img_data[np.newaxis, :, :, :]
amc178  = t178_am_img_data[np.newaxis, :, :, :]
amc179  = t179_am_img_data[np.newaxis, :, :, :]
amc180  = t180_am_img_data[np.newaxis, :, :, :]
amc181  = t181_am_img_data[np.newaxis, :, :, :]
amc182  = t182_am_img_data[np.newaxis, :, :, :]

# %%
amc173  = np.concatenate((amc1, amc2, amc3, amc4, amc5, amc6, amc7, amc8, amc9, amc10,
                          amc11, amc12, amc13, amc14, amc15, amc16, amc17, amc18, amc19, amc20,
                          amc21, amc22, amc23, amc24, amc25, amc26, amc27, amc28, amc29, amc30,
                          amc31, amc32, amc33, amc34, amc35, amc36, amc37, amc38, amc39, amc40,
                          amc41, amc42, amc43, amc44, amc45, amc46, amc47, amc48, amc49, amc50,
                          amc51, amc52, amc53, amc54, amc55, amc56, amc57, amc58, amc59, amc60,
                          amc61, amc62, amc63, amc64, amc65, amc66, amc67, amc68, amc69, amc70,
                          amc71, amc72, amc73, amc74, amc75, amc76, amc77, amc78, amc79, amc80,
                          amc81, amc82, amc83, amc84, amc85, amc86, amc87, amc88, amc89, amc90,
                          amc91, amc92, amc93, amc94, amc95, amc96, amc97, amc98, amc99, amc100,
                          amc101, amc102, amc103, amc104, amc105, amc106, amc107, amc108, amc109, amc110,
                          amc111, amc112, amc113, amc114, amc115, amc116, amc117, amc118, amc119, amc120,
                          amc121, amc122, amc123, amc124, amc125, amc126, amc127, amc128, amc129, amc130,
                          amc131, amc132, amc133, amc134, amc135, amc136, amc137, amc138, amc139, amc140,
                          amc141, amc142, amc143, amc144, amc145, amc146, amc147, amc148, 
                                                                  amc156,         amc158,         amc160,
                          amc161, amc162, amc163, amc164, amc165, amc166, amc167, amc168, amc169, amc170,
                          amc171, amc172, amc173, amc174, amc175, amc176, amc177, amc178, amc179, amc180,
                          amc181, amc182))

# %%
ydat1 = pd.read_csv('C:/Users/Majnu/Desktop/MJ.Desk/Tossi/COBRE/Data.May.2023/nobpclass.csv', sep=',', header = None)
ydat = ydat1.to_numpy()

# %%
acc_rslts_vec = np.empty(25)

DefaultConv2D = partial(keras.layers.Conv2D,
                        kernel_size=3, activation='relu', padding="SAME")

for m in range(0, 25):
    print(m)
    indx = np.arange(173, dtype = int)
    np.random.seed(m)
    np.random.shuffle(indx)
    indx1 = indx[:138]
    indx2 = indx[138:]
    indx1a = indx1[:120]
    indx1b = indx1[120:]

    X_train, X_valid, X_test = amc173[indx1a], amc173[indx1b], amc173[indx2]
    y_train, y_valid, y_test = ydat[indx1a,], ydat[indx1b,], ydat[indx2,]
    
    model = keras.models.Sequential([
        keras.layers.Conv2D(filters = 64, kernel_size = (3,3)),
        keras.layers.BatchNormalization(),
        keras.layers.MaxPooling2D(pool_size=2),
        keras.layers.Conv2D(filters = 128, kernel_size = (2,2)),
   
        keras.layers.Flatten(),

        keras.layers.Dense(512, activation="relu"),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(512, activation="relu"),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(512, activation="relu"),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(512, activation="relu"),
        keras.layers.Dropout(0.5),
    
        keras.layers.Dense(units=1, activation='sigmoid'),
    ])

    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = model.fit(X_train, y_train, epochs = 30, verbose = 0, validation_data=(X_valid, y_valid))
    rslts = model.evaluate(X_test, y_test, verbose = 0)
    print(rslts[1])
    acc_rslts_vec[m] = rslts[1]
# Out:
# 0
# 0.6857143044471741
# 1
# 0.5714285969734192
# 2
# 0.6000000238418579
# 3
# 0.6000000238418579
# 4
# 0.6000000238418579
# 5
# 0.6285714507102966
# 6
# 0.6285714507102966
# 7
# 0.5142857432365417
# 8
# 0.5142857432365417
# 9
# 0.5142857432365417
# 10
# 0.7428571581840515
# 11
# 0.6285714507102966
# 12
# 0.5714285969734192
# 13
# 0.5428571701049805
# 14
# 0.6571428775787354
# 15
# 0.6285714507102966
# 16
# 0.5428571701049805
# 17
# 0.7142857313156128
# 18
# 0.6285714507102966
# 19
# 0.5714285969734192
# 20
# 0.6571428775787354
# 21
# 0.5714285969734192
# 22
# 0.5428571701049805
# 23
# 0.6000000238418579
# 24
# 0.6571428775787354

# %%
np.median(acc_rslts_vec[0:25])
# Out:
# 0.6000000238418579

# %%
np.mean(acc_rslts_vec[0:25])
# Out:
# 0.6045714521408081

# %%
np.min(acc_rslts_vec[0:25])
# Out:
# 0.5142857432365417

# %%
np.max(acc_rslts_vec[0:25])
# Out:
# 0.7428571581840515

# %%
np.quantile(acc_rslts_vec[0:25], 0.25)
# Out:
# 0.5714285969734192

# %%
np.quantile(acc_rslts_vec[0:25], 0.75)
# Out:
# 0.6285714507102966
